# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('./cars-dataset.csv')
data
# Out:
# /var/folders/s8/ryzdv1sn1g15nt9h4886lz7m0000gn/T/ipykernel_90420/2345151528.py:1: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('./cars-dataset.csv')
#        Unnamed: 0                          Model   Serie Company  \
# 0               0             AC Ace (1993-1996)     Ace      AC
# 1               1           AC Aceca (1998-2000)   Aceca      AC
# 2               2           AC Aceca (1998-2000)   Aceca      AC
# 3               3     AC Cobra MkIII (1965-1967)   Cobra      AC
# 4               4  AC Cobra 378 MkIV (1965-1967)   Cobra      AC
# ...           ...                            ...     ...     ...
# 29787       29787         2026 Zenvo Aurora Agil  Aurora   Zenvo
# 29788       29788          2026 Zenvo Aurora Tur  Aurora   Zenvo
# 29789       29789       Zenvo TS1 (2017-Present)     TS1   Zenvo
# 29790       29790     Zenvo TSR-S (2018-Present)   TSR-S   Zenvo
# ...

# %%
unique = data['Company'].unique()
unique
# Out:
# array(['AC', 'ACURA', 'ALFA ROMEO', 'ALPINE', 'ARIEL', 'ARO', 'ARTEGA',
#        'ASTON MARTIN', 'AUDI', 'AURUS', 'BENTLEY', 'BMW', 'BRISTOL',
#        'BUFORI', 'BUGATTI', 'BUICK', 'CADILLAC', 'CATERHAM', 'CHEVROLET',
#        'CHRYSLER', 'CITROEN', 'CUPRA', 'DACIA', 'DAEWOO', 'DAIHATSU',
#        'DATSUN', 'DeLorean', 'DODGE', 'DONKERVOORT', 'DR MOTOR',
#        'DS AUTOMOBILES', 'EAGLE', 'FERRARI', 'FIAT', 'FISKER', 'FORD',
#        'FSO', 'GEELY', 'GENESIS', 'GMC', 'GORDON MURRAY Automotive',
#        'GTA Motor', 'HINDUSTAN', 'HOLDEN', 'HONDA', 'HUMMER', 'HYUNDAI',
#        'INEOS', 'INFINITI', 'ISUZU', 'JAGUAR', 'JEEP', 'Karma', 'KIA',
#        'KOENIGSEGG', 'KTM', 'LADA', 'LAMBORGHINI', 'LANCIA', 'LAND ROVER',
#        'LEXUS', 'LIGHTYEAR', 'LINCOLN', 'LOTUS', 'Lucid Motors',
#        'Mahindra', 'MARUSSIA', 'MARUTI SUZUKI', 'MASERATI', 'MAYBACH',
#        'MAZDA', 'MCLAREN', 'MERCEDES BENZ', 'Mercedes-AMG', 'MERCURY',
# ...

# %%
#nan per column
nan = data.isnull().sum()
nan
# Out:
# Unnamed: 0                               0
# Model                                    0
# Serie                                    0
# Company                                  0
# Body style                            7554
# Segment                                  0
# Production years                         0
# Cylinders                              522
# Displacement                           996
# Power(HP)                              566
# Power(BHP)                             566
# Power(KW)                              566
# Torque(lb-ft)                         1072
# Torque(Nm)                            1072
# Electrical motor power               29059
# Electrical motor torque              29271
# Fuel System                            212
# Fuel                                    65
# Fuel capacity                         8199
# Top Speed                             4433
# Acceleration 0-62 Mph (0-100 kph)     5125
# Drive Type                             165
# ...

# %%
columns = data.columns
columns
# Out:
# Index(['Unnamed: 0', 'Model', 'Serie', 'Company', 'Body style', 'Segment',
#        'Production years', 'Cylinders', 'Displacement', 'Power(HP)',
#        'Power(BHP)', 'Power(KW)', 'Torque(lb-ft)', 'Torque(Nm)',
#        'Electrical motor power', 'Electrical motor torque', 'Fuel System',
#        'Fuel', 'Fuel capacity', 'Top Speed',
#        'Acceleration 0-62 Mph (0-100 kph)', 'Drive Type', 'Gearbox',
#        'Front brake', 'Rear brake', 'Tire Size', 'Length', 'Width', 'Height',
#        'Front/rear Track', 'Wheelbase', 'Ground Clearance',
#        'Aerodynamics (Cd)', 'Aerodynamics (frontal area)', 'Turning circle',
#        'Cargo Volume', 'Unladen Weight', 'Gross Weight Limit', 'Combined mpg',
#        'City mpg', 'Highway mpg', 'CO2 Emissions', 'CO2 Emissions (Combined)',
#        'Turning circle (curb to curb)', 'Total maximum power', 'Power pack',
#        'Nominal Capacity', 'Top speed (electrical)', 'EV Range', 'High mpg',
# ...

# %%
#count number of columns
count = data.count()
count
# Out:
# Unnamed: 0                           29792
# Model                                29792
# Serie                                29792
# Company                              29792
# Body style                           22238
# Segment                              29792
# Production years                     29792
# Cylinders                            29270
# Displacement                         28796
# Power(HP)                            29226
# Power(BHP)                           29226
# Power(KW)                            29226
# Torque(lb-ft)                        28720
# Torque(Nm)                           28720
# Electrical motor power                 733
# Electrical motor torque                521
# Fuel System                          29580
# Fuel                                 29727
# Fuel capacity                        21593
# Top Speed                            25359
# Acceleration 0-62 Mph (0-100 kph)    24667
# Drive Type                           29627
# ...
